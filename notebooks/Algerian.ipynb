# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv')

# %%
dataset.head()
# Out:
#    day month  year Temperature   RH   Ws  Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 0  NaN   NaN   NaN         NaN  NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 1    1     6  2012          29   57   18     0  65.7  3.4  7.6  1.3  3.4  0.5
# 2    2     6  2012          29   61   13   1.3  64.4  4.1  7.6    1  3.9  0.4
# 3    3     6  2012          26   82   22  13.1  47.1  2.5  7.1  0.3  2.7  0.1
# 4    4     6  2012          25   89   13   2.5  28.6  1.3  6.9    0  1.7    0
#
#     Classes
# 0       NaN
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %% [markdown]
# # Data Cleaning

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain  \
# 0                              NaN   NaN   NaN         NaN  NaN  NaN  NaN
# 123                            NaN   NaN   NaN         NaN  NaN  NaN  NaN
# 124  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 169                             14     7  2012          37   37   18  0.2
#
#      FFMC   DMC      DC   ISI   BUI   FWI Classes
# 0     NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 123   NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 124   NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 169  88.9  12.9  14.6 9  12.5  10.4  fire     NaN

# %%
dataset.loc[:122,"Region"] = 0 #to 122 raw assigned value 0
dataset.loc[122:,"Region"] = 1 #from 122 assigned value 1
df = dataset

# %%
df[["Region"]] = df[["Region"]].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       248 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 29.2+ KB

# %%
df = df.dropna().reset_index(drop=True)

# %%
df.iloc[122]
# Out:
# day                    day
# month                month
# year                  year
# Temperature    Temperature
# RH                      RH
# Ws                      Ws
# Rain                  Rain
# FFMC                  FFMC
# DMC                    DMC
# DC                      DC
# ISI                    ISI
# BUI                    BUI
# FWI                    FWI
# Classes            Classes
# Region                   1
# Name: 122, dtype: object

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df.columns = df.columns.str.strip() #Removing Unnecessary space
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
objects = [features for features in df.columns if df[features].dtypes == 'O']

# %%
objects
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
for i in objects:
    if i != 'Classes':
        df[i] = df[i].astype(float)

# %%
df.to_csv("Cleaned_Dataset.csv",index = False)

# %% [markdown]
# # EDA

# %%
df_copy = df.drop(['day' , 'month' , 'year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire       0

# %%
df_copy["Classes"].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
# df_copy['Classes'] np.where(df_copy['Classes'].str.contains('not fire'),0,1) this is to convert remaining data into fires and not fire

# %%
plt.style.use('seaborn')
df_copy.hist(bins = 50 , figsize=(20,15))
plt.show()
# Out:
# /tmp/ipykernel_70/2559789967.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Percentage for pie chart
percentage = df_copy['Classes'].value_counts(normalize=True)*100

# %%
classlables = ['Fire' , 'Not fire']
plt.figure(figsize=(12,7))
plt.pie(percentage,labels = classlables,autopct='%1.1f%%')
plt.title("Pie Chart of classes")
plt.show()

# %% [markdown]
# # Correlation

# %%
df_copy.corr()
# Out:
# /tmp/ipykernel_70/382007831.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_copy.corr()
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# /tmp/ipykernel_70/4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <AxesSubplot: >

# %%
sns.boxplot(df['FWI'],color='green')
# Out:
# <AxesSubplot: >

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
df['Classes'] = np.where(df['Classes'].str.contains('not fire'), 'not fire' , 'fire')

# %%
# Monthly fire analysis
dftemp = df.loc[df['Region'] == 1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month' , hue='Classes' , data=df)
plt.ylabel('Number of Fires ' , weight = 'bold')
plt.xlabel('Months' , weight = 'bold')
plt.title('Fire analysis of sidi - Bel Regions' , weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Fire analysis of sidi - Bel Regions')

# %%
# Monthly fire analysis
dftemp = df.loc[df['Region'] == 0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month' , hue='Classes' , data=df)
plt.ylabel('Number of Fires ' , weight = 'bold')
plt.xlabel('Months' , weight = 'bold')
plt.title('Fire analysis of Barjaia Regions' , weight = 'bold')
# Out:
# Text(0.5, 1.0, 'Fire analysis of Barjaia Regions')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Cleaned_Dataset.csv')
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# ...

# %%
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI   Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5  not fire
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4  not fire
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1  not fire
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0  not fire
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5  not fire
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...       ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5      fire
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0  not fire
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2  not fire
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7  not fire
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5  not fire
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
df['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %% [markdown]
# # Depentdent And independent Feature dividing

# %%
from sklearn.model_selection import train_test_split

# %%
## Independent And dependent features
x=df.drop('FWI',axis=1)
y=df['FWI']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,y_train.shape,x_test.shape
# Out:
# ((194, 11), (194,), (49, 11))

# %%
x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.653725 -0.308149 -0.313112  0.690285  0.468911
# RH             -0.653725  1.000000  0.211645  0.239441 -0.649239 -0.401836
# Ws             -0.308149  0.211645  1.000000  0.235922 -0.176596  0.004712
# Rain           -0.313112  0.239441  0.235922  1.000000 -0.547864 -0.288538
# FFMC            0.690285 -0.649239 -0.176596 -0.547864  1.000000  0.611978
# DMC             0.468911 -0.401836  0.004712 -0.288538  0.611978  1.000000
# DC              0.372163 -0.220945  0.092866 -0.301110  0.519513  0.876122
# ISI             0.613138 -0.714640 -0.002300 -0.349903  0.751819  0.679049
# BUI             0.446280 -0.346511  0.037465 -0.299179  0.598248  0.983891
# Classes         0.539642 -0.454926 -0.075322 -0.378585  0.786012  0.606775
# Region          0.238037 -0.397364 -0.208736 -0.054379  0.230579  0.178501
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrics = dataset.corr()
    for i in range(len(corr_matrics.columns)):
        for j in range(i):
            if abs(corr_matrics.iloc[i, j]) > threshold:
                colname = corr_matrics.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold--Domain expertise
corr_features=correlation(x_train,0.85)

# %%
corr_features #Common Features
# Out:
# {'BUI', 'DC'}

# %%
## drop features when correlation is more than 0.85
x_train.drop(corr_features,axis=1,inplace=True)
x_test.drop(corr_features,axis=1,inplace=True)
x_train.shape,x_test.shape
# Out:
# ((194, 9), (49, 9))

# %% [markdown]
# # Feature Scaling or Standerdization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC   ISI  Classes  Region
# 115           29  65  19   0.6  68.3   5.5   1.5        0       0
# 207           33  37  16   0.0  92.2  61.3  13.1        1       1
# 158           38  43  13   0.5  85.0  13.0   4.1        1       1
# 132           31  42  21   0.0  90.6  18.2  13.4        1       1
# 84            34  64  14   0.0  88.9  40.5   9.0        1       0
# ..           ...  ..  ..   ...   ...   ...   ...      ...     ...
# 106           24  82  15   0.4  44.9   0.9   0.2        0       0
# 14            28  80  17   3.1  49.4   3.0   0.4        0       0
# 92            25  76  17   7.2  46.0   1.3   0.2        0       0
# 179           34  59  16   0.0  88.1  19.5   7.4        1       1
# 102           30  77  21   1.8  58.5   1.9   1.1        0       0
#
# [194 rows x 9 columns]

# %% [markdown]
# # Box Plots To understand Effect Of Standard Scaler

# %%
plt.subplots(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(data=x_train)
plt.title('X_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=x_train_scaled)
plt.title('X_train After Scaling')
# Out:
# /tmp/ipykernel_70/2457960331.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(x_train_scaled,y_train)
y_pred=linreg.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.5034072886824766
# R2 Score 0.9805507766134701

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso=Lasso()
lasso.fit(x_train_scaled,y_train)
y_pred=lasso.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 1.0093958923873407
# R2 Score 0.9430507350726562

# %% [markdown]
# # Ridge Regression Model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(x_train_scaled,y_train)
y_pred=ridge.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.5147414846348966
# R2 Score 0.9800884245010251

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))
